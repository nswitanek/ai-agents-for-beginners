# %%
import asyncio
import os
import json
import requests

from dotenv import load_dotenv  # For loading environment variables securely
from random import randint

# These are the core components for building tool-enabled agents
from agent_framework import ChatAgent           # Main agent class
from agent_framework import ai_function # Decorator for defining AI functions (tools)
from agent_framework.azure import AzureOpenAIChatClient  # Azure OpenAI-compatible client

# Pydantic for strong typing and data validation in tool definitions
from typing import Annotated
from pydantic import Field

# Load environment variables from .env file for secure configuration
load_dotenv()
# Out:
# True

# %%
# i had copied over the self in the function definition by mistake remove it
def booking_hotel(
    query: Annotated[str, "The name of the city"], 
    check_in_date: Annotated[str, "Hotel Check-in Time"], 
    check_out_date: Annotated[str, "Hotel Check-out Time"],
) -> Annotated[str, "Return the result of booking hotel information"]:
    """
    Function to book a hotel.
    Parameters:
    - query: The name of the city
    - check_in_date: Hotel Check-in Time
    - check_out_date: Hotel Check-out Time
    Returns:
    - The result of booking hotel information
    """

    # Define the parameters for the hotel booking request
    params = {
        "engine": "google_hotels",
        "q": query,
        "check_in_date": check_in_date,
        "check_out_date": check_out_date,
        "adults": "1",
        "currency": "USD",
        "gl": "us",
        "hl": "en",
        "api_key": os.environ.get("SERP_API_KEY")
    }

    serp_base_url = os.environ.get("SERP_API_BASE_URL") or "https://serpapi.com/search"
    
    response = requests.get(serp_base_url, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the response content as JSON
        response = response.json()
        # Return the properties from the response
        return response["properties"]
    else:
        # Return None if the request failed
        return "request failed"

# %%
booking_hotel("new york", "2026-07-01", "2026-07-05")
# Out:
# [{'type': 'hotel',
#   'name': 'Canal Loft Hotel',
#   'description': 'Modest budget hotel with relaxed rooms & dorms, plus a casual lounge with a TV',
#   'property_token': 'ChoI1cnoyd6s64-RARoNL2cvMTFoY3l4eG01eRAB',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=1&check_in_date=2026-07-01&check_out_date=2026-07-05&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChoI1cnoyd6s64-RARoNL2cvMTFoY3l4eG01eRAB&q=new+york',
#   'gps_coordinates': {'latitude': 40.7152965, 'longitude': -73.9938841},
#   'check_in_time': '4:00\u202fPM',
#   'check_out_time': '11:00\u202fAM',
#   'rate_per_night': {'lowest': '$231',
#    'extracted_lowest': 231,
#    'before_taxes_fees': '$202',
#    'extracted_before_taxes_fees': 202},
#   'total_rate': {'lowest': '$924',
#    'extracted_lowest': 924,
#    'before_taxes_fees': '$809',
#    'extracted_before_taxes_fees': 809},
#   'deal': '33% less than usual',
#   'deal_description': 'Great Deal',
#   'nearby_places': [{'name': 'Brooklyn Bridge',
#     'transportations': [{'type': 'Taxi', 'duration': '6 min'}]},
#    {'name': 'East Broadway',
#     'transportations': [{'type': 'Walking', 'duration': '5 min'}]},
#    {'name': 'John F. Kennedy International Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '37 min'},
#      {'type': 'Public transport', 'duration': '1 hr 3 min'}]},
#    {'name': 'Bacaro',
#     'transportations': [{'type': 'Walking', 'duration': '4 min'}]}],
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPUNrNZTEbSe86vz8KnZsI80aS-BJbvM5RL2OFO=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipN6JJb5IA8X366Rnd0P60uMmjCdZXuPFgY5w91z=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipN6JJb5IA8X366Rnd0P60uMmjCdZXuPFgY5w91z=s10000'}],
#   'overall_rating': 3.4,
#   'reviews': 701,
#   'ratings': [{'stars': 5, 'count': 225},
#    {'stars': 4, 'count': 165},
#    {'stars': 3, 'count': 108},
#    {'stars': 2, 'count': 46},
#    {'stars': 1, 'count': 157}],
#   'location_rating': 4.7,
#   'reviews_breakdown': [{'name': 'Sleep',
#     'description': 'Sleep',
#     'total_mentioned': 122,
#     'positive': 47,
#     'negative': 56,
#     'neutral': 19},
#    {'name': 'Cleanliness',
#     'description': 'Cleanliness',
#     'total_mentioned': 149,
#     'positive': 91,
#     'negative': 49,
#     'neutral': 9},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 149,
#     'positive': 58,
#     'negative': 81,
#     'neutral': 10},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 162,
#     'positive': 85,
#     'negative': 64,
#     'neutral': 13},
#    {'name': 'Bathroom',
#     'description': 'Bathroom and toiletries',
#     'total_mentioned': 70,
#     'positive': 24,
#     'negative': 39,
#     'neutral': 7},
#    {'name': 'Location',
#     'description': 'Location',
#     'total_mentioned': 89,
#     'positive': 69,
#     'negative': 7,
#     'neutral': 13}],
#   'amenities': ['Free Wi-Fi',
#    'Air conditioning',
#    'Accessible',
#    'Kid-friendly',
#    'Smoke-free property']},
#  {'type': 'hotel',
#   'name': 'The Flat NYC - Hotel & Event Space New York',
#   'link': 'https://www.theflatnyc.com/',
#   'property_token': 'ChkI_NeBj7HPnLQzGg0vZy8xMWgxMWprODJsEAE',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=1&check_in_date=2026-07-01&check_out_date=2026-07-05&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChkI_NeBj7HPnLQzGg0vZy8xMWgxMWprODJsEAE&q=new+york',
#   'gps_coordinates': {'latitude': 40.743083, 'longitude': -73.99065220000001},
#   'check_in_time': '3:00\u202fPM',
#   'check_out_time': '11:00\u202fAM',
#   'rate_per_night': {'lowest': '$192',
#    'extracted_lowest': 192,
#    'before_taxes_fees': '$164',
#    'extracted_before_taxes_fees': 164},
#   'total_rate': {'lowest': '$768',
#    'extracted_lowest': 768,
#    'before_taxes_fees': '$657',
#    'extracted_before_taxes_fees': 657},
#   'nearby_places': [{'name': 'Flatiron Building',
#     'transportations': [{'type': 'Walking', 'duration': '4 min'}]},
#    {'name': '23 St',
#     'transportations': [{'type': 'Walking', 'duration': '4 min'}]},
#    {'name': 'John F. Kennedy International Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '40 min'},
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNIdewDDACXPwai1Pmo0OAyLc6lCFfJYzMQ90Py=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipONvlnKo1VDGzei1mCy0VFrJJWqOaGyFqoAUBCx=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipONvlnKo1VDGzei1mCy0VFrJJWqOaGyFqoAUBCx=s10000'}],
#   'overall_rating': 4.1,
#   'reviews': 279,
#   'ratings': [{'stars': 5, 'count': 151},
#    {'stars': 4, 'count': 66},
#    {'stars': 3, 'count': 30},
#    {'stars': 2, 'count': 12},
#    {'stars': 1, 'count': 20}],
#   'location_rating': 4.7,
#   'reviews_breakdown': [{'name': 'Bathroom',
#     'description': 'Bathroom and toiletries',
#     'total_mentioned': 62,
#     'positive': 30,
#     'negative': 22,
#     'neutral': 10},
#    {'name': 'Accessibility',
#     'description': 'Accessibility',
#     'total_mentioned': 28,
#     'positive': 5,
#     'negative': 13,
#     'neutral': 10},
#    {'name': 'Sleep',
#     'description': 'Sleep',
#     'total_mentioned': 58,
#     'positive': 19,
#     'negative': 28,
#     'neutral': 11},
#    {'name': 'Location',
#     'description': 'Location',
#     'total_mentioned': 64,
#     'positive': 57,
#     'negative': 2,
#     'neutral': 5},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 81,
#     'positive': 58,
#     'negative': 19,
#     'neutral': 4},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 59,
#     'positive': 46,
#     'negative': 12,
#     'neutral': 1}],
#   'amenities': ['Wi-Fi',
#    'Parking',
#    'Air conditioning',
#    'Smoke-free property']},
#  {'type': 'hotel',
#   'name': 'Kama Central Park',
#   'description': 'Streamlined berths in a trendy capsule hostel featuring a coffee shop, lockers & Wi-Fi.',
#   'link': 'http://kamahostel.com/',
#   'property_token': 'ChkIxID07d3Q-6s7Gg0vZy8xMXRzOW5mMWpwEAE',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=1&check_in_date=2026-07-01&check_out_date=2026-07-05&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChkIxID07d3Q-6s7Gg0vZy8xMXRzOW5mMWpwEAE&q=new+york',
#   'gps_coordinates': {'latitude': 40.7981293, 'longitude': -73.9609289},
#   'check_in_time': '3:00\u202fPM',
#   'check_out_time': '11:00\u202fAM',
#   'rate_per_night': {'lowest': '$94',
#    'extracted_lowest': 94,
#    'before_taxes_fees': '$79',
#    'extracted_before_taxes_fees': 79},
#   'total_rate': {'lowest': '$375',
#    'extracted_lowest': 375,
#    'before_taxes_fees': '$315',
#    'extracted_before_taxes_fees': 315},
#   'nearby_places': [{'name': 'Central Park',
#     'transportations': [{'type': 'Walking', 'duration': '2 min'}]},
#    {'name': 'Central Park West/W 106 St',
#     'transportations': [{'type': 'Walking', 'duration': '1 min'}]},
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNff3VXzWoYzbUzXt1WBLngIhBaQbnzlSUDRjhG=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipM18f-NP1StGf3DtVCzFXIFPENjYQbLmLz9NS_W=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipM18f-NP1StGf3DtVCzFXIFPENjYQbLmLz9NS_W=s10000'}],
#   'overall_rating': 4,
#   'reviews': 355,
#   'ratings': [{'stars': 5, 'count': 207},
#    {'stars': 4, 'count': 52},
#    {'stars': 3, 'count': 38},
#    {'stars': 2, 'count': 16},
#    {'stars': 1, 'count': 42}],
#   'location_rating': 3.6,
#   'reviews_breakdown': [{'name': 'Location',
#     'description': 'Location',
#     'total_mentioned': 91,
#     'positive': 84,
#     'negative': 6,
#     'neutral': 1},
#    {'name': 'Bathroom',
#     'description': 'Bathroom and toiletries',
#     'total_mentioned': 55,
#     'positive': 20,
#     'negative': 27,
#     'neutral': 8},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 111,
#     'positive': 84,
#     'negative': 25,
#     'neutral': 2},
#    {'name': 'Sleep',
#     'description': 'Sleep',
#     'total_mentioned': 60,
#     'positive': 30,
#     'negative': 25,
#     'neutral': 5},
#    {'name': 'Cleanliness',
#     'description': 'Cleanliness',
#     'total_mentioned': 84,
#     'positive': 63,
#     'negative': 20,
#     'neutral': 1},
#    {'name': 'Air Conditioning',
#     'description': 'Air conditioning',
#     'total_mentioned': 18,
#     'positive': 6,
#     'negative': 10,
#     'neutral': 2}],
#   'amenities': ['Breakfast ($)',
#    'Free Wi-Fi',
#    'Air conditioning',
#    'Pet-friendly',
#    'Kitchen in some rooms',
#    'Smoke-free property']},
#  {'type': 'hotel',
#   'name': 'The Local NY',
#   'description': 'Dorms & private rooms in an industrial-chic hostel with free Wi-Fi, a hip bar & a rooftop terrace.',
#   'link': 'http://thelocalny.com/',
#   'property_token': 'ChkI9-qC-POBs-dYGg0vZy8xMWJicmxqMHBwEAE',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=1&check_in_date=2026-07-01&check_out_date=2026-07-05&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChkI9-qC-POBs-dYGg0vZy8xMWJicmxqMHBwEAE&q=new+york',
#   'gps_coordinates': {'latitude': 40.749595, 'longitude': -73.947825},
#   'check_in_time': '4:00\u202fPM',
#   'check_out_time': '11:00\u202fAM',
#   'rate_per_night': {'lowest': '$146',
#    'extracted_lowest': 146,
#    'before_taxes_fees': '$124',
#    'extracted_before_taxes_fees': 124},
#   'total_rate': {'lowest': '$583',
#    'extracted_lowest': 583,
#    'before_taxes_fees': '$496',
#    'extracted_before_taxes_fees': 496},
#   'nearby_places': [{'name': 'Court Sq-23 St',
#     'transportations': [{'type': 'Walking', 'duration': '6 min'}]},
#    {'name': 'John F. Kennedy International Airport',
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipONoG9jIlsqpWAFGzeoF8D0rlMzi0D7oHy90QN0=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipONoG9jIlsqpWAFGzeoF8D0rlMzi0D7oHy90QN0=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipO4tzVKBZcz_Tdcba6VxDoW2BCua-AM7emRPvtK=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipO4tzVKBZcz_Tdcba6VxDoW2BCua-AM7emRPvtK=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipM5Frlp7UDFpPtlCj1LPXhV_Uax3EGS-B9SGXK0=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipM5Frlp7UDFpPtlCj1LPXhV_Uax3EGS-B9SGXK0=s10000'}],
#   'overall_rating': 4.4,
#   'reviews': 1392,
#   'ratings': [{'stars': 5, 'count': 899},
#    {'stars': 4, 'count': 316},
#    {'stars': 3, 'count': 75},
#    {'stars': 2, 'count': 38},
#    {'stars': 1, 'count': 64}],
#   'location_rating': 3.5,
#   'reviews_breakdown': [{'name': 'Bar',
#     'description': 'Bar or lounge',
#     'total_mentioned': 252,
#     'positive': 217,
#     'negative': 15,
#     'neutral': 20},
#    {'name': 'Dining',
#     'description': 'Food and Beverage',
#     'total_mentioned': 151,
#     'positive': 127,
#     'negative': 11,
#     'neutral': 13},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 350,
#     'positive': 293,
#     'negative': 46,
#     'neutral': 11},
#    {'name': 'Location',
#     'description': 'Location',
#     'total_mentioned': 223,
#     'positive': 187,
#     'negative': 7,
#     'neutral': 29},
#    {'name': 'Cleanliness',
#     'description': 'Cleanliness',
#     'total_mentioned': 238,
#     'positive': 203,
#     'negative': 28,
#     'neutral': 7},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 344,
#     'positive': 278,
#     'negative': 43,
#     'neutral': 23}],
#   'amenities': ['Free Wi-Fi',
#    'Air conditioning',
#    'Bar',
#    'Accessible',
#    'Business center',
#    'Smoke-free property']},
#  {'type': 'hotel',
#   'name': 'Hotel Park Ave',
#   'description': 'Plush property featuring a Mediterranean restaurant, a rooftop bar & an ultra-hip nightclub.',
#   'link': 'https://hotelparkave.com/?utm_source=google&utm_medium=local&utm_campaign=hotel-park-ave',
#   'property_token': 'ChkIuZvChs3BhpFcGg0vZy8xMWYwNDFrY3J6EAE',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=1&check_in_date=2026-07-01&check_out_date=2026-07-05&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChkIuZvChs3BhpFcGg0vZy8xMWYwNDFrY3J6EAE&q=new+york',
#   'gps_coordinates': {'latitude': 40.7447966, 'longitude': -73.98323599999999},
#   'check_in_time': '3:00\u202fPM',
#   'check_out_time': '12:00\u202fPM',
#   'rate_per_night': {'lowest': '$268',
#    'extracted_lowest': 268,
#    'before_taxes_fees': '$230',
#    'extracted_before_taxes_fees': 230},
#   'total_rate': {'lowest': '$1,071',
#    'extracted_lowest': 1071,
#    'before_taxes_fees': '$922',
#    'extracted_before_taxes_fees': 922},
#   'deal': '62% less than usual',
#   'deal_description': 'Great Deal',
#   'nearby_places': [{'name': 'Empire State Building',
#     'transportations': [{'type': 'Walking', 'duration': '8 min'}]},
#    {'name': '28 St',
#     'transportations': [{'type': 'Walking', 'duration': '3 min'}]},
#    {'name': 'John F. Kennedy International Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '35 min'},
#      {'type': 'Public transport', 'duration': '56 min'}]},
#    {'name': 'Mason Jar NYC',
#     'transportations': [{'type': 'Walking', 'duration': '1 min'}]}],
#   'hotel_class': '4-star hotel',
#   'extracted_hotel_class': 4,
#   'images': [{'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNYi87dWXoiwIaD2w6H1lD0_r2Zr28jkShGtPpt=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNYi87dWXoiwIaD2w6H1lD0_r2Zr28jkShGtPpt=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNDItf6hwl2cRknlJqRHDN_RoHeSwp_ad8W_jeY=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNDItf6hwl2cRknlJqRHDN_RoHeSwp_ad8W_jeY=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNVRWQ1hZaOUL5TKLBZIKqM949_r_XV7KN0k9L0=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNVRWQ1hZaOUL5TKLBZIKqM949_r_XV7KN0k9L0=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPzzEg--To5poJhRLvYX4T68LDuWDZrT3AkgDA9=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPzzEg--To5poJhRLvYX4T68LDuWDZrT3AkgDA9=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipN4ubXgOSjusprNxyseMtLyybvCsLMN5Aqay3Iu=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipN4ubXgOSjusprNxyseMtLyybvCsLMN5Aqay3Iu=s10000'},
#    {'thumbnail': 'https://lh5.googleusercontent.com/proxy/z_p9-b-5aV3wa5cnqxCBQ-gKutqDMPRwTqZC--swi_Zetg2nCtjhY7dciOe7OanxXKO5bn0ycRThOkR03DTYU7qxj0u_BTtzie2dsqvX3Qbl_4ZpnlJSGDV-UDOIVqjL5SgRR0w4zM2FfXJi_NFBha1vdiRavA=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/30/92/ff/5c/studio-balcony-suite.jpg?w=1500&h=1000&s=1'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNFXqXmJCu9YWutxiljatqQ833L0STbewR75Quf=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNFXqXmJCu9YWutxiljatqQ833L0STbewR75Quf=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPDdeFQk57wSvZbvjAy9afrHE-ppmBSY9AXZZgv=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPDdeFQk57wSvZbvjAy9afrHE-ppmBSY9AXZZgv=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMgWJvL8fLQUfUXs-Wv-8vYPsOnMIVUDlvBo1vA=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMgWJvL8fLQUfUXs-Wv-8vYPsOnMIVUDlvBo1vA=s10000'}],
#   'overall_rating': 3.8,
#   'reviews': 991,
#   'ratings': [{'stars': 5, 'count': 480},
#    {'stars': 4, 'count': 189},
#    {'stars': 3, 'count': 94},
#    {'stars': 2, 'count': 68},
#    {'stars': 1, 'count': 160}],
#   'location_rating': 4.8,
#   'reviews_breakdown': [{'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 314,
#     'positive': 171,
#     'negative': 125,
#     'neutral': 18},
#    {'name': 'Room',
#     'description': 'Room amenities',
#     'total_mentioned': 159,
#     'positive': 50,
#     'negative': 98,
#     'neutral': 11},
#    {'name': 'Bar',
#     'description': 'Bar or lounge',
#     'total_mentioned': 87,
#     'positive': 47,
#     'negative': 29,
#     'neutral': 11},
#    {'name': 'Breakfast',
#     'description': 'Breakfast',
#     'total_mentioned': 104,
#     'positive': 42,
#     'negative': 47,
#     'neutral': 15},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 318,
#     'positive': 176,
#     'negative': 110,
#     'neutral': 32},
#    {'name': 'Location',
#     'description': 'Location',
#     'total_mentioned': 158,
#     'positive': 123,
#     'negative': 22,
#     'neutral': 13}],
#   'amenities': ['Breakfast ($)',
#    'Free Wi-Fi',
#    'Parking ($)',
#    'Air conditioning',
#    'Pet-friendly',
#    'Fitness center',
#    'Bar',
#    'Restaurant',
#    'Full-service laundry',
#    'Accessible',
#    'Kid-friendly',
#    'Smoke-free property'],
#   'eco_certified': True},
#  {'type': 'hotel',
#   'name': 'NY Moore Hostel',
#   'description': 'No-frills spot with modern dorms and private rooms, as well as free Wi-Fi & an equipped kitchen.',
#   'link': 'http://www.nymoorehostel.com/',
#   'property_token': 'ChgIpsXMgO3Nv6efARoLL2cvMXRma3JwcGYQAQ',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=1&check_in_date=2026-07-01&check_out_date=2026-07-05&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChgIpsXMgO3Nv6efARoLL2cvMXRma3JwcGYQAQ&q=new+york',
#   'gps_coordinates': {'latitude': 40.7043676, 'longitude': -73.9376324},
#   'check_in_time': '2:00\u202fPM',
#   'check_out_time': '11:00\u202fAM',
#   'rate_per_night': {'lowest': '$69',
#    'extracted_lowest': 69,
#    'before_taxes_fees': '$57',
#    'extracted_before_taxes_fees': 57},
#   'total_rate': {'lowest': '$276',
#    'extracted_lowest': 276,
#    'before_taxes_fees': '$229',
#    'extracted_before_taxes_fees': 229},
#   'nearby_places': [{'name': 'Morgan Av',
#     'transportations': [{'type': 'Walking', 'duration': '7 min'}]},
#    {'name': 'John F. Kennedy International Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '38 min'},
#      {'type': 'Public transport', 'duration': '1 hr 1 min'}]},
#    {'name': 'Blanca',
#     'transportations': [{'type': 'Walking', 'duration': '5 min'}]}],
#   'hotel_class': '2-star hotel',
#   'extracted_hotel_class': 2,
#   'images': [{'thumbnail': 'https://lh3.googleusercontent.com/proxy/3g2kGMwP-FK0wvX574_6tAq1sQipD9EQUJPf5zguTP5htzgWlaRT29cgrT_TzXR_H__JqnuyTkNxqHi37IeAzAR6U4xZfC7iqeZ0tNBWFGFCyS_n5HbTcqOXgn2_0UhCjz7_hYv8xU1MXCPIgUgkzh4xKe72Vw=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://images.trvl-media.com/lodging/8000000/7810000/7803500/7803456/85698df7_z.jpg'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPUBlxXE5_AzqxoDVKdb-4q5r7uSRaOGMpi8oRB=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPUBlxXE5_AzqxoDVKdb-4q5r7uSRaOGMpi8oRB=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMEENmbVnL6UPnqL303VCQ2bicUXh3j9k3ooy4e=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMEENmbVnL6UPnqL303VCQ2bicUXh3j9k3ooy4e=s10000'},
#    {'thumbnail': 'https://lh5.googleusercontent.com/proxy/koxQirM5Hou5MdPrTdQOQ3jtF5iYhxbZm-EoW_YuilR6FIPwyiOoFr8NjkOG08x3myMm6SFk7Ii4Jr5xqrv8vCnrV1NO_WMOESKCq8AquRTDBWOI25vdjxAVhNsy9hHUJbZYzQUmLnwRv9zx7bqvmYJL9bet4g=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://images.trvl-media.com/lodging/8000000/7810000/7803500/7803456/60e58485_z.jpg'},
#    {'thumbnail': 'https://lh6.googleusercontent.com/proxy/GaBFVmQ0jJ2bkVz-_WIu0wTPySTzQ4fGTMnl6xqpzF_6AJdmRFhVRDe4_ba5uZZ7Y6rTaO8d5swRnNfRjMMnyASpfPIpam9cg4GpzejA0ms_v02f4tQRW6OTp-__VFkk0DzdqQQLrpncufaQw1WD2cq4oCNhL6w=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0e/cf/0e/53/ny-moore-hostel.jpg?w=2100&h=1400&s=1'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMBxlfJ--3OAIlCKtg0cnPZjhWuMR8k3B63ano-=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMBxlfJ--3OAIlCKtg0cnPZjhWuMR8k3B63ano-=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMDP06GFKJymbiLtmKIaANnhfwgT2v5TN7_XMuv=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMDP06GFKJymbiLtmKIaANnhfwgT2v5TN7_XMuv=s10000'},
#    {'thumbnail': 'https://lh6.googleusercontent.com/proxy/bohFaKYCxjsXn98PUaf0KQY5QZT-U2qwQaUt_IDVfBR-Vf7TdxvVU3gKsFXTTaWgUlHKyz63FeOf0S2M4iNHp1iqu-jfOIiDHHihhc_A5P4CJ_69RZwzLBZwJ6rRZR1-sGZ7gBd0sS0yRkfMfMZ_UqKtKTCO2as=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://photos.hotelbeds.com/giata/original/68/689317/689317a_hb_a_001.jpg'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMP9FNbJ4uchg6P7I03sp8Y-y3Y3R5raGZ8S5uR=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMP9FNbJ4uchg6P7I03sp8Y-y3Y3R5raGZ8S5uR=s10000'}],
#   'overall_rating': 4.2,
#   'reviews': 1070,
#   'ratings': [{'stars': 5, 'count': 609},
#    {'stars': 4, 'count': 268},
#    {'stars': 3, 'count': 87},
#    {'stars': 2, 'count': 43},
#    {'stars': 1, 'count': 63}],
#   'location_rating': 3.9,
#   'reviews_breakdown': [{'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 299,
#     'positive': 246,
#     'negative': 43,
#     'neutral': 10},
#    {'name': 'Sleep',
#     'description': 'Sleep',
#     'total_mentioned': 148,
#     'positive': 76,
#     'negative': 48,
#     'neutral': 24},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 293,
#     'positive': 247,
#     'negative': 29,
#     'neutral': 17},
#    {'name': 'Kitchen',
#     'description': 'Kitchen',
#     'total_mentioned': 70,
#     'positive': 51,
#     'negative': 8,
#     'neutral': 11},
#    {'name': 'Location',
#     'description': 'Location',
#     'total_mentioned': 163,
#     'positive': 125,
#     'negative': 20,
#     'neutral': 18},
#    {'name': 'Cleanliness',
#     'description': 'Cleanliness',
#     'total_mentioned': 194,
#     'positive': 162,
#     'negative': 25,
#     'neutral': 7}],
#   'amenities': ['Free Wi-Fi',
#    'Parking',
#    'Air conditioning',
#    'Accessible',
#    'Smoke-free property']},
#  {'type': 'hotel',
#   'name': 'New York Spirit Retreats',
#   'description': 'Snug rooms with shared bathrooms in an unassuming adults-only hostel offering a lounge & a library.',
#   'link': 'https://newyorkspiritretreats.com/',
#   'property_token': 'ChoIs8me5LDMqPKPARoNL2cvMTFzdjAyZ2djdBAB',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=1&check_in_date=2026-07-01&check_out_date=2026-07-05&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChoIs8me5LDMqPKPARoNL2cvMTFzdjAyZ2djdBAB&q=new+york',
#   'gps_coordinates': {'latitude': 40.748658899999995,
#    'longitude': -73.99565249999999},
#   'check_in_time': '3:00\u202fPM',
#   'check_out_time': '11:00\u202fAM',
#   'rate_per_night': {'lowest': '$144',
#    'extracted_lowest': 144,
#    'before_taxes_fees': '$144',
#    'extracted_before_taxes_fees': 144},
#   'total_rate': {'lowest': '$578',
#    'extracted_lowest': 578,
#    'before_taxes_fees': '$578',
#    'extracted_before_taxes_fees': 578},
#   'nearby_places': [{'name': 'The High Line',
#     'transportations': [{'type': 'Walking', 'duration': '9 min'}]},
#    {'name': 'Penn Station',
#     'transportations': [{'type': 'Walking', 'duration': '4 min'}]},
#    {'name': 'John F. Kennedy International Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '42 min'},
#      {'type': 'Public transport', 'duration': '1 hr 1 min'}]},
#    {'name': 'Citizens Of Chelsea',
#     'transportations': [{'type': 'Walking', 'duration': '7 min'}]}],
#   'images': [{'thumbnail': 'https://lh3.googleusercontent.com/gps-cs-s/AG0ilSx5j-JgDm5TVdDW0vMePKK7LDnAscLf22IdKaN1LrP5hLSuOirn_NtH9z2z-oTXD399cfYrFrF6cnoCFjh4T45zS5As16usmLCGV1nshw72T8Rm64Kh8rpenlPpXMuwZ7u4hkxr=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/CIHM0ogKEICAgICbqPeXvgE=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNaF-MacBbQEe1LIJssM9NRFyecwSw26XoL4yv7=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNaF-MacBbQEe1LIJssM9NRFyecwSw26XoL4yv7=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNdGkmY8wuKG_GuZtMXp9ExIaklKqvdj8iCmZBB=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNdGkmY8wuKG_GuZtMXp9ExIaklKqvdj8iCmZBB=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPZHi_ge6pdBhUMdRuvTdZsNnzsy5aD1e0xIMlt=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPZHi_ge6pdBhUMdRuvTdZsNnzsy5aD1e0xIMlt=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNM-_L-S7A55meHwkNmRCGU5VzoDIrfGSwa9rNA=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNM-_L-S7A55meHwkNmRCGU5VzoDIrfGSwa9rNA=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipOAtswWfxFCfLIzq-XS28h4SSAc8XfX2qssvdId=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOAtswWfxFCfLIzq-XS28h4SSAc8XfX2qssvdId=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMGKHRd7l7oJfwvTtUsFsaltnVTeYm1xGIg7_i3=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMGKHRd7l7oJfwvTtUsFsaltnVTeYm1xGIg7_i3=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPBmpeSLAG32OhDg-nznUWn_qwU_p37i9UjKpzc=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPBmpeSLAG32OhDg-nznUWn_qwU_p37i9UjKpzc=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNVk2Ui4Zq4hBSYLcUOs5GGU-We7PkmC8l7zcPz=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNVk2Ui4Zq4hBSYLcUOs5GGU-We7PkmC8l7zcPz=s10000'}],
#   'overall_rating': 4.8,
#   'reviews': 469,
#   'ratings': [{'stars': 5, 'count': 422},
#    {'stars': 4, 'count': 16},
#    {'stars': 3, 'count': 9},
#    {'stars': 2, 'count': 9},
#    {'stars': 1, 'count': 13}],
#   'location_rating': 3.9,
#   'reviews_breakdown': [{'name': 'Breakfast',
#     'description': 'Breakfast',
#     'total_mentioned': 100,
#     'positive': 95,
#     'negative': 3,
#     'neutral': 2},
#    {'name': 'Location',
#     'description': 'Location',
#     'total_mentioned': 141,
#     'positive': 130,
#     'negative': 2,
#     'neutral': 9},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 196,
#     'positive': 182,
#     'negative': 11,
#     'neutral': 3},
#    {'name': 'Restaurant',
#     'description': 'Restaurant',
#     'total_mentioned': 45,
#     'positive': 43,
#     'negative': 2,
#     'neutral': 0},
#    {'name': 'Safety',
#     'description': 'Safety',
#     'total_mentioned': 35,
#     'positive': 28,
#     'negative': 5,
#     'neutral': 2},
#    {'name': 'Sleep',
#     'description': 'Sleep',
#     'total_mentioned': 48,
#     'positive': 27,
#     'negative': 15,
#     'neutral': 6}],
#   'amenities': ['Free breakfast',
#    'Free Wi-Fi',
#    'Parking ($)',
#    'Air conditioning',
#    'Smoke-free property']},
#  {'type': 'hotel',
#   'name': 'Manhattan Bowery Lodge',
#   'description': 'Utilitarian rooms in an unassuming hostel offering a communal kitchen & complimentary Wi-Fi.',
#   'link': 'http://manhattanbowerylodgeny.us/',
#   'property_token': 'ChgIw7vY0J7lqOr_ARoLL2cvMXRkNHFta3gQAQ',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=1&check_in_date=2026-07-01&check_out_date=2026-07-05&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChgIw7vY0J7lqOr_ARoLL2cvMXRkNHFta3gQAQ&q=new+york',
#   'gps_coordinates': {'latitude': 40.7167625, 'longitude': -73.9955368},
#   'check_in_time': '1:00\u202fPM',
#   'check_out_time': '11:30\u202fAM',
#   'rate_per_night': {'lowest': '$124',
#    'extracted_lowest': 124,
#    'before_taxes_fees': '$105',
#    'extracted_before_taxes_fees': 105},
#   'total_rate': {'lowest': '$496',
#    'extracted_lowest': 496,
#    'before_taxes_fees': '$420',
#    'extracted_before_taxes_fees': 420},
#   'nearby_places': [{'name': 'Washington Square Park',
#     'transportations': [{'type': 'Taxi', 'duration': '8 min'}]},
#    {'name': 'Grand St',
#     'transportations': [{'type': 'Walking', 'duration': '4 min'}]},
#    {'name': 'John F. Kennedy International Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '37 min'},
#      {'type': 'Public transport', 'duration': '1 hr 6 min'}]},
#    {'name': 'TLK- Tigerlily Kitchen (TAKEOUT & CATERING)',
#     'transportations': [{'type': 'Walking', 'duration': '2 min'}]}],
#   'hotel_class': '2-star hotel',
#   'extracted_hotel_class': 2,
#   'images': [{'thumbnail': 'https://lh3.googleusercontent.com/proxy/0IA-SkMx44QN-wfh_4LcqqH_an1e_K4_jYYdiuOdrMM5Hhx1VkUfC7enD7LviYAVMvuxj1yN6YMAftBimi4Xtlayy6uCz9Y-0UhEgJT_hLBqUtmbBHZdqrOUXQnhAQEeqPNkhQ60FV-WxaF0BlDe79kaZhc8Rg=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://images.trvl-media.com/lodging/14000000/13170000/13164100/13164075/4474d967_z.jpg'},
#    {'thumbnail': 'https://lh6.googleusercontent.com/proxy/Zo2KszWN45-074vb6U1BqgovVB3HppvSHfh9fDrMwhtu-odFwolO6jXWH-s_skVV8yDPxTbOqRogVOSlXiWjtELP4X4m6u-ZNtGABAvXUjciMaWcxXsQ0UutCDvI9xlLcS5I0LVfHmmr2q0MurH9p9hkMxAP3g=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://images.trvl-media.com/lodging/14000000/13170000/13164100/13164075/f8dcbced_z.jpg'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/gps-cs-s/AG0ilSzMmnJ4Crn6WGZp7An0icU9CkNvHMLOrkE3QRTZx-pJPAWZdORaGYlHnxVRg56mC0MP4juNDjOu3pNUR3wQegWuI6hlK6P6WK_OFcJJSXFtI4A2YfIycO7EZ-NuIlxaFkbhXcE5uqQ5Ad4=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/CIABIhC9ftsDdJO4gnNWYn-5pOax=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/gps-cs-s/AG0ilSxzmuWL4JRTUsdMLj6MXezrUWkGtWrOaUCT8R_d3tIeQdYFHKZMVoFYLVemMpy4SHObIio_RTDC3wnYZE0CEdIq2Er0RL41AhQ15-wwd-YWc4jhyvoYSa6gGaR8Lm2t4g0Cn9gU9g=s287-w287-h192-n-k-no-v1',
#    {'stars': 1, 'count': 71}],
#   'location_rating': 4.9,
#   'reviews_breakdown': [{'name': 'Bathroom',
#     'description': 'Bathroom and toiletries',
#     'total_mentioned': 52,
#     'positive': 20,
#     'negative': 26,
#     'neutral': 6},
#    {'name': 'Sleep',
#     'description': 'Sleep',
#     'total_mentioned': 50,
#     'positive': 15,
#     'negative': 26,
#     'neutral': 9},
#    {'name': 'Cleanliness',
#     'description': 'Cleanliness',
#     'total_mentioned': 50,
#     'positive': 23,
#     'negative': 20,
#     'neutral': 7},
#    {'name': 'Location',
#     'description': 'Location',
#     'total_mentioned': 39,
#     'positive': 28,
#     'negative': 6,
#     'neutral': 5},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 53,
#     'positive': 15,
#     'negative': 32,
#     'neutral': 6},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 41,
#     'positive': 26,
#     'negative': 12,
#     'neutral': 3}],
#   'amenities': ['Free Wi-Fi', 'Parking', 'Smoke-free property']},
#  {'type': 'hotel',
#   'name': 'Bklyn House',
#   'link': 'https://bklynhousehotel.com/',
#   'property_token': 'ChkI6ITh99TZzcdbGg0vZy8xMW1jdF9zamM5EAE',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=1&check_in_date=2026-07-01&check_out_date=2026-07-05&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChkI6ITh99TZzcdbGg0vZy8xMW1jdF9zamM5EAE&q=new+york',
#   'gps_coordinates': {'latitude': 40.700763699999996,
#    'longitude': -73.9393097},
#   'check_in_time': '3:00\u202fPM',
#   'check_out_time': '12:00\u202fPM',
#   'rate_per_night': {'lowest': '$168',
#    'extracted_lowest': 168,
#    'before_taxes_fees': '$143',
#    'extracted_before_taxes_fees': 143},
#   'total_rate': {'lowest': '$673',
#    'extracted_lowest': 673,
#    'before_taxes_fees': '$574',
#    'extracted_before_taxes_fees': 574},
#   'deal': '53% less than usual',
#   'deal_description': 'Great Deal',
#   'nearby_places': [{'name': 'Flushing Av/Beaver St',
#     'transportations': [{'type': 'Walking', 'duration': '1 min'}]},
#    {'name': 'John F. Kennedy International Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '41 min'},
#      {'type': 'Public transport', 'duration': '56 min'}]},
#    {'name': 'J.K. & Sons',
#     'transportations': [{'type': 'Walking', 'duration': '2 min'}]}],
#   'hotel_class': '3-star hotel',
#   'extracted_hotel_class': 3,
#   'images': [{'thumbnail': 'https://lh5.googleusercontent.com/proxy/ndfz4xj5D5D96admkv0sQOpBOEsVwQOZ5I7EhU2aKNUKSfArVls5CcCdi192dXJh_a99I7DPxU4jXpK6iEJ9MYXEWZ8D_WV74VAjfIVY7XT6f6dtjbMPbS1NoiLLzS1k05c59MNImE5Dr3Z798EhjmB76X8M4ZA=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://images.trvl-media.com/lodging/10000000/9720000/9711500/9711491/4709d5d0_z.jpg'},
#    {'thumbnail': 'https://lh6.googleusercontent.com/proxy/yO7sglGG8S0jBrFoEKGekdzhC3wfGmR91Q0xAe7nVoGQr2x6TY1MJVLUglQCYwd1lQ6WmjX6pfrxPkgyF6krqKpt-tizHr3TbaskyE90jDjM-8UCNCbuTudP1HUDdYx43Jtha7SiML-TjqYgLbNIl-Cff6yhuw=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://photos.hotelbeds.com/giata/original/55/556950/556950a_hb_l_001.jpg'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipODqVPHaK2rXYJkgyu2XAS9o23nLcUHZltb02BD=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipODqVPHaK2rXYJkgyu2XAS9o23nLcUHZltb02BD=s10000'}],
#   'overall_rating': 3.8,
#   'reviews': 121,
#   'ratings': [{'stars': 5, 'count': 68},
#    {'stars': 4, 'count': 14},
#    {'stars': 3, 'count': 10},
#    {'stars': 2, 'count': 7},
#    {'stars': 1, 'count': 22}],
#   'location_rating': 3.6,
#   'reviews_breakdown': [{'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 64,
#     'positive': 48,
#     'negative': 16,
#     'neutral': 0},
#    {'name': 'Sleep',
#     'description': 'Sleep',
#     'total_mentioned': 27,
#     'positive': 9,
#     'negative': 15,
#     'neutral': 3},
#    {'name': 'Location',
#     'description': 'Location',
#     'total_mentioned': 33,
#     'positive': 30,
#     'negative': 1,
#     'neutral': 2},
#    {'name': 'Cleanliness',
#     'description': 'Cleanliness',
#     'total_mentioned': 31,
#     'positive': 21,
#     'negative': 9,
#     'neutral': 1},
#    {'name': 'Transit',
#     'description': 'Public transit',
#     'total_mentioned': 12,
#     'positive': 10,
#     'negative': 0,
#     'neutral': 2},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 42,
#     'positive': 25,
#     'negative': 14,
#     'neutral': 3}],
#   'amenities': ['Free Wi-Fi',
#    'Air conditioning',
#    'Pet-friendly',
#    'Accessible',
#    'Kid-friendly',
#    'Smoke-free property']},
#  {'type': 'hotel',
#   'name': 'Chelsea International Hostel',
#   'description': 'Simple dorms & private rooms in a low-key lodging in Chelsea, plus continental breakfast.',
#   'link': 'http://www.chelseahostel.com/',
#   'property_token': 'ChgI85PL4pmV3LOYARoLL2cvMXcwc2RzcngQAQ',
# ...
#     'total_mentioned': 1577,
#     'positive': 1223,
#     'negative': 216,
#     'neutral': 138},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 1684,
#     'positive': 934,
#     'negative': 662,
#     'neutral': 88},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 1998,
#     'positive': 1160,
#     'negative': 652,
#     'neutral': 186},
#    {'name': 'Bathroom',
#     'description': 'Bathroom and toiletries',
#     'total_mentioned': 663,
#     'positive': 76,
#     'negative': 530,
#     'neutral': 57},
#    {'name': 'Bar',
#     'description': 'Bar or lounge',
#     'total_mentioned': 321,
#     'positive': 153,
#     'negative': 128,
#     'neutral': 40},
#    {'name': 'Business',
#     'description': 'Business',
#     'total_mentioned': 243,
#     'positive': 135,
#     'negative': 55,
#     'neutral': 53}],
#   'amenities': ['Free Wi-Fi',
#    'Parking ($)',
#    'Air conditioning',
#    'Fitness center',
#    'Bar',
#    'Restaurant',
#    'Room service',
#    'Full-service laundry',
#    'Accessible',
#    'Business center',
#    'Smoke-free property'],
#   'eco_certified': True},
#  {'type': 'hotel',
#   'name': 'Tribeca Hotel FiDi',
#   'link': 'http://tribecahotelfidi.com/',
#   'property_token': 'ChkI76euw7SW5pEvGg0vZy8xMXczcnE1eHl3EAE',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=1&check_in_date=2026-07-01&check_out_date=2026-07-05&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChkI76euw7SW5pEvGg0vZy8xMXczcnE1eHl3EAE&q=new+york',
#   'gps_coordinates': {'latitude': 40.7084445, 'longitude': -74.0136601},
#   'check_in_time': '3:00\u202fPM',
#   'check_out_time': '11:00\u202fAM',
#   'rate_per_night': {'lowest': '$215',
#    'extracted_lowest': 215,
#    'before_taxes_fees': '$184',
#    'extracted_before_taxes_fees': 184},
#   'total_rate': {'lowest': '$859',
#    'extracted_lowest': 859,
#    'before_taxes_fees': '$736',
#    'extracted_before_taxes_fees': 736},
#   'nearby_places': [{'name': '9/11 Memorial & Museum',
#     'transportations': [{'type': 'Walking', 'duration': '2 min'}]},
#    {'name': 'Rector St',
#     'transportations': [{'type': 'Walking', 'duration': '1 min'}]},
#    {'name': 'John F. Kennedy International Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '43 min'},
#      {'type': 'Public transport', 'duration': '1 hr 3 min'}]},
#    {'name': 'ZAZA',
#     'transportations': [{'type': 'Walking', 'duration': '1 min'}]}],
#   'hotel_class': '3-star hotel',
#   'extracted_hotel_class': 3,
#   'images': [{'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNoB9dB2xhztTsW5G_3ObEuXvWbrQFeGbTXzs2x=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNoB9dB2xhztTsW5G_3ObEuXvWbrQFeGbTXzs2x=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipOra5pZ0rVP82zZpisacLd1WtGHwaXdyw9mUW21=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOra5pZ0rVP82zZpisacLd1WtGHwaXdyw9mUW21=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPzRhFQDWYjstYI8a58O-t2vhXNhdc67FCxuDgv=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPzRhFQDWYjstYI8a58O-t2vhXNhdc67FCxuDgv=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPtIiN0Z8P8ZBFdKZvVK6ZF0tijQB7cquLKynoi=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPtIiN0Z8P8ZBFdKZvVK6ZF0tijQB7cquLKynoi=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMd_yhZA3cfg70OT0q2s7heYGRYu3OEFzwFmMeG=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMd_yhZA3cfg70OT0q2s7heYGRYu3OEFzwFmMeG=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipOq-skhYcDhWo2Xou5mUbwKdZtIB9Nms-5BpzLT=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOq-skhYcDhWo2Xou5mUbwKdZtIB9Nms-5BpzLT=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipP0MZoCO0HRiqj1PuOMN78Bk9ZkKENGpywcKP-3=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipP0MZoCO0HRiqj1PuOMN78Bk9ZkKENGpywcKP-3=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMQkmTKeYQcVct2NoOTcnVQI3IqKzxoVOUJn_ib=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMQkmTKeYQcVct2NoOTcnVQI3IqKzxoVOUJn_ib=s10000'},
#    {'thumbnail': 'https://lh5.googleusercontent.com/proxy/HqqfooIC4rLv18WXOdfRY2Lyf5NQaoUEfqk10pqDEt1BU2oj-552gpqlcgY32o2-NM9tymgsOg2ZWcXKYQGmkHBwtysEJmK9zhYQZm2hGJRdZmqz0BeSNKXpPlyj25q_NzCPJY2nioQW2RJ8I7v7bFZSQjY-UgM=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://photos.hotelbeds.com/giata/original/10/1065884/1065884a_hb_ro_003.jpg'}],
#   'overall_rating': 3.9,
#   'reviews': 167,
#   'ratings': [{'stars': 5, 'count': 95},
#    {'stars': 4, 'count': 22},
#    {'stars': 3, 'count': 8},
#    {'stars': 2, 'count': 16},
#    {'stars': 1, 'count': 26}],
#   'location_rating': 4.4,
#   'reviews_breakdown': [{'name': 'Room',
#     'description': 'Room amenities',
#     'total_mentioned': 41,
#     'positive': 18,
#     'negative': 21,
#     'neutral': 2},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 78,
#     'positive': 65,
#     'negative': 12,
#     'neutral': 1},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 87,
#     'positive': 51,
#     'negative': 31,
#     'neutral': 5},
#    {'name': 'Air Conditioning',
#     'description': 'Air conditioning',
#     'total_mentioned': 15,
#     'positive': 3,
#     'negative': 11,
#     'neutral': 1},
#    {'name': 'Location',
#     'description': 'Location',
#     'total_mentioned': 60,
#     'positive': 46,
#     'negative': 11,
#     'neutral': 3},
#    {'name': 'Sleep',
#     'description': 'Sleep',
#     'total_mentioned': 45,
#     'positive': 14,
#     'negative': 28,
#     'neutral': 3}],
#   'amenities': ['Free Wi-Fi',
#    'Air conditioning',
#    'Pet-friendly',
#    'Kitchen in some rooms',
#    'Smoke-free property']},
#  {'type': 'hotel',
#   'name': 'Off Soho Suites',
#   'description': 'Loft-style lodging with sleek suites (some with shared kitchens & baths) & an art gallery.',
#   'link': 'http://www.offsoho.com/',
#   'property_token': 'ChcI2c7njNCbxcsVGgsvZy8xdGtubGMxeRAB',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=1&check_in_date=2026-07-01&check_out_date=2026-07-05&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChcI2c7njNCbxcsVGgsvZy8xdGtubGMxeRAB&q=new+york',
#   'gps_coordinates': {'latitude': 40.7212799, 'longitude': -73.9927143},
#   'check_in_time': '3:00\u202fPM',
#   'check_out_time': '12:00\u202fPM',
#   'rate_per_night': {'lowest': '$268',
#    'extracted_lowest': 268,
#    'before_taxes_fees': '$229',
#    'extracted_before_taxes_fees': 229},
#   'total_rate': {'lowest': '$1,073',
#    'extracted_lowest': 1073,
#    'before_taxes_fees': '$916',
#    'extracted_before_taxes_fees': 916},
#   'deal': '36% less than usual',
#   'deal_description': 'Great Deal',
#   'nearby_places': [{'name': 'Brooklyn Bridge',
#     'transportations': [{'type': 'Taxi', 'duration': '9 min'}]},
#    {'name': '2 Av',
#     'transportations': [{'type': 'Walking', 'duration': '6 min'}]},
#    {'name': 'John F. Kennedy International Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '37 min'},
#      {'type': 'Public transport', 'duration': '1 hr 7 min'}]},
#    {'name': 'Freemans',
#     'transportations': [{'type': 'Walking', 'duration': '1 min'}]}],
#   'hotel_class': '2-star hotel',
#   'extracted_hotel_class': 2,
#   'images': [{'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPaTSLGFqyaUR5bXzn-i_2xcevuq_xoGO26o-zh=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPaTSLGFqyaUR5bXzn-i_2xcevuq_xoGO26o-zh=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipOc0NTht_oGreyNZTe3u5ejZM7rfLHxJSPFY9IE=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOc0NTht_oGreyNZTe3u5ejZM7rfLHxJSPFY9IE=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipM-fZFnJSTI96ciDB4q4THslHhqfhqA2PmqxvQY=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipM-fZFnJSTI96ciDB4q4THslHhqfhqA2PmqxvQY=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/proxy/g6M3YbijNROudpxoDuQYCOTk9xbi7t9Kw-GjyJE5FDXsYhDczh85xf2Odkp9V_g9n9Zs092K-rHZbaTURg4ERKbdxF5Vp5AA9hWvrk2XhCiMvlqeeVRJQfWH7IkELujKGDitKi2p2-oquosn8Vd6fPloHlkI2Ug=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://photos.hotelbeds.com/giata/original/32/324428/324428a_hb_w_024.jpg'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMHqdnRYxc_H0AH6-GSLUFM0q-Wn521kDgHj1ov=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMHqdnRYxc_H0AH6-GSLUFM0q-Wn521kDgHj1ov=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipOymrMkIr-ZRS8LtFlDPdgVtVJpJfqIu71eF0Kr=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOymrMkIr-ZRS8LtFlDPdgVtVJpJfqIu71eF0Kr=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipOO2jBJC3MZQd1o_M_y7wF7Su07dWM3zT2DRb-_=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOO2jBJC3MZQd1o_M_y7wF7Su07dWM3zT2DRb-_=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipM80nVHoMzXtqoMVhuJvRZSp6WlVBw3gIn6EAsF=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipM80nVHoMzXtqoMVhuJvRZSp6WlVBw3gIn6EAsF=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNrtZijMni9VASerjSOg4pqcr5dK0VoLN03A6R1=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNrtZijMni9VASerjSOg4pqcr5dK0VoLN03A6R1=s10000'}],
#   'overall_rating': 4.2,
#   'reviews': 403,
#   'ratings': [{'stars': 5, 'count': 213},
#    {'stars': 4, 'count': 106},
#    {'stars': 3, 'count': 44},
#    {'stars': 2, 'count': 20},
#    {'stars': 1, 'count': 20}],
#   'location_rating': 4.9,
#   'reviews_breakdown': [{'name': 'Kitchen',
#     'description': 'Kitchen',
#     'total_mentioned': 54,
#     'positive': 40,
#     'negative': 9,
#     'neutral': 5},
#    {'name': 'Location',
#     'description': 'Location',
#     'total_mentioned': 111,
#     'positive': 103,
#     'negative': 3,
#     'neutral': 5},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 103,
#     'positive': 85,
#     'negative': 15,
#     'neutral': 3},
#    {'name': 'Sleep',
#     'description': 'Sleep',
#     'total_mentioned': 48,
#     'positive': 22,
#     'negative': 19,
#     'neutral': 7},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 101,
#     'positive': 71,
#     'negative': 23,
#     'neutral': 7},
#    {'name': 'Room',
#     'description': 'Room amenities',
#     'total_mentioned': 35,
#     'positive': 15,
#     'negative': 17,
#     'neutral': 3}],
#   'amenities': ['Free Wi-Fi',
#    'Parking ($)',
#    'Air conditioning',
#    'Pet-friendly',
#    'Fitness center',
#    'Kitchen',
#    'Accessible',
#    'Kid-friendly',
#    'Smoke-free property']},
#  {'type': 'hotel',
#   'name': 'Pointe Plaza Hotel',
#   'description': 'Casual hotel offering loft-style suites with full kitchens & soaking tubs, plus a gym & free Wi-Fi.',
#   'link': 'https://www.pointeplazahotel.com/',
#   'property_token': 'ChkI8a7Oza_Zv8X_ARoML2cvMWhjMHR2a2Z2EAE',
#   'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=1&check_in_date=2026-07-01&check_out_date=2026-07-05&children=0&currency=USD&engine=google_hotels&gl=us&hl=en&property_token=ChkI8a7Oza_Zv8X_ARoML2cvMWhjMHR2a2Z2EAE&q=new+york',
#   'gps_coordinates': {'latitude': 40.6992512, 'longitude': -73.95914549999999},
#   'check_in_time': '3:00\u202fPM',
#   'check_out_time': '11:00\u202fAM',
#   'rate_per_night': {'lowest': '$232',
#    'extracted_lowest': 232,
#    'before_taxes_fees': '$199',
#    'extracted_before_taxes_fees': 199},
#   'total_rate': {'lowest': '$930',
#    'extracted_lowest': 930,
#    'before_taxes_fees': '$798',
#    'extracted_before_taxes_fees': 798},
#   'deal': '27% less than usual',
#   'deal_description': 'Great Deal',
#   'nearby_places': [{'name': 'John F. Kennedy International Airport',
#     'transportations': [{'type': 'Taxi', 'duration': '32 min'},
#      {'type': 'Public transport', 'duration': '1 hr 10 min'}]},
#    {'name': 'Hole In The Wall',
#     'transportations': [{'type': 'Taxi', 'duration': '9 min'}]}],
#   'hotel_class': '3-star hotel',
#   'extracted_hotel_class': 3,
#   'images': [{'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPeqfInaVT4k2Na4h-OS0izyjF9wWzSGoMCLuZY=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPeqfInaVT4k2Na4h-OS0izyjF9wWzSGoMCLuZY=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMDozNuod9JfGt68RiD7Jrabdza1Dj9Wi8zuU8y=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMDozNuod9JfGt68RiD7Jrabdza1Dj9Wi8zuU8y=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipPvfVVNOdpntUFQWVhI9T2tze8KRdNyNzp8d4vq=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPvfVVNOdpntUFQWVhI9T2tze8KRdNyNzp8d4vq=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNttS4ygoKVOXo-sJQSSPYS3q7Tno9jxjdygfff=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNttS4ygoKVOXo-sJQSSPYS3q7Tno9jxjdygfff=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMHf3eLWlhN8Tj-s0JIznUyuGqp-YCrBdQuzN9L=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMHf3eLWlhN8Tj-s0JIznUyuGqp-YCrBdQuzN9L=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipOd_MqDq32AWPqmLp5fAg6deGaZCtImOHwEdjHt=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOd_MqDq32AWPqmLp5fAg6deGaZCtImOHwEdjHt=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipNQZO98yG9OQYkGoZPpalezi2Tg8mG7QA1y5KhE=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNQZO98yG9OQYkGoZPpalezi2Tg8mG7QA1y5KhE=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMQTjtuO0SnYdft7QnE6BQQuakvNDhu8yfqvPVf=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMQTjtuO0SnYdft7QnE6BQQuakvNDhu8yfqvPVf=s10000'},
#    {'thumbnail': 'https://lh3.googleusercontent.com/p/AF1QipMdKIxyD78nut7_0Q1tXr7MtvpxcjvQILyFB4e1=s287-w287-h192-n-k-no-v1',
#     'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMdKIxyD78nut7_0Q1tXr7MtvpxcjvQILyFB4e1=s10000'}],
#   'overall_rating': 4.2,
#   'reviews': 1095,
#   'ratings': [{'stars': 5, 'count': 636},
#    {'stars': 4, 'count': 210},
#    {'stars': 3, 'count': 121},
#    {'stars': 2, 'count': 46},
#    {'stars': 1, 'count': 82}],
#   'location_rating': 3.3,
#   'reviews_breakdown': [{'name': 'Breakfast',
#     'description': 'Breakfast',
#     'total_mentioned': 90,
#     'positive': 51,
#     'negative': 30,
#     'neutral': 9},
#    {'name': 'Service',
#     'description': 'Service',
#     'total_mentioned': 253,
#     'positive': 206,
#     'negative': 33,
#     'neutral': 14},
#    {'name': 'Property',
#     'description': 'Property',
#     'total_mentioned': 284,
#     'positive': 217,
#     'negative': 43,
#     'neutral': 24},
#    {'name': 'Cleanliness',
#     'description': 'Cleanliness',
#     'total_mentioned': 195,
#     'positive': 153,
#     'negative': 37,
#     'neutral': 5},
#    {'name': 'Sleep',
#     'description': 'Sleep',
#     'total_mentioned': 104,
#     'positive': 50,
#     'negative': 42,
#     'neutral': 12},
#    {'name': 'Kitchen',
#     'description': 'Kitchen',
#     'total_mentioned': 53,
#     'positive': 26,
#     'negative': 20,
#     'neutral': 7}],
#   'amenities': ['Breakfast',
#    'Free Wi-Fi',
#    'Parking ($)',
#    'Air conditioning',
#    'Fitness center',
#    'Restaurant',
#    'Airport shuttle',
#    'Accessible',
#    'Business center',
#    'Kid-friendly',
#    'Smoke-free property']}]
